# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Mathplotlib Basic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Subplots in Matplotlib

# %% [markdown]
# ## Object orintent way

# %% [markdown]
# ## type of plots

# %% [markdown]
# ## Saving plots

# %% [markdown]
# ## Working with images

# %% [markdown]
# ## Design
