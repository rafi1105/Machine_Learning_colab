# %% [markdown]
# <a href="https://colab.research.google.com/github/rafi1105/Machine_Learning_colab/blob/main/Data%20Visualization/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Mathplotlib Basic

# %%
x= np.linspace(0,5,11) # (start_num,end_num,how many num between them)
y= x**2

# %%
plt.plot(x,y, color='red',linewidth=2)
plt.title('x and y line graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# ## Subplots in Matplotlib

# %%
plt.subplot(2,2,1) #num_row,num_col,select num of row and col # make matrix
plt.plot(x**2,y/4,'y')
plt.subplot(2,2,4)
plt.plot(x,y,'r') # 'color'
plt.subplot(2,2,3)
plt.plot(y,x,'b')
plt.subplot(2,2,2)
plt.plot(x,y,'g')

# %% [markdown]
# ## Object orintent way

# %%
fig= plt.figure(figsize=(6,4), dpi= 100) #axis the canves #control the canves #(width,height) #show more clear resulation default =100
axis1=fig.add_axes([.1,0.1,.8,.8]) # (y-axis, x-axis, width, height) calculated in %
axis1.plot(x,y)

axis2=fig.add_axes([.1,0.4,.3,.3]) #overlap
axis2.plot(x,y,'g')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fig= plt.figure(figsize=(6,4), dpi= 100) #axis the canves #control the canves #(width,height) #show more clear resulation default =100
#       2 axis1=fig.add_axes([.1,0.1,.8,.8]) # (y-axis, x-axis, width, height) calculated in %
#       3 axis1.plot(x,y)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Type of plots

# %%
plt.scatter(x,y)

# %%
from random import sample
data= sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 8., 11.,  8.,  8., 14., 12., 16., 10.,  6.,  7.]),
#  array([ 16. , 113.9, 211.8, 309.7, 407.6, 505.5, 603.4, 701.3, 799.2,
#         897.1, 995. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Saving plots

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7caba3177190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7caba3174410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7caba3f0c0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7caba3176d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7caba3174cd0>],
#  'means': []}

# %% [markdown]
# ## Working with images

# %% [markdown]
# ###Saving plot

# %%
fig=plt.figure()
ax=fig.add_axes([.1,.1,.8,.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# ###image

# %%
import matplotlib.image as mpimg
img = mpimg.imread('/content/image.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1999.5), np.float64(1999.5), np.float64(-0.5))

# %%
crop = img[50:500,500:900]  #crop row, cols
plt.imshow(crop)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(449.5), np.float64(-0.5))

# %% [markdown]
# ## Design

# %%
plt.subplot(2,2,1)
plt.plot(x,y, 'r', lw=3, ls='--',marker='s')
plt.subplot(2,2,2)
plt.plot(x,y, 'y', lw=3, ls=':',marker='o')
plt.subplot(2,2,3)
plt.plot(x,y, 'y', lw=3, ls=':',marker='*', markersize=10)
plt.subplot(2,2,4)
plt.plot(x,y, 'b', lw=3, ls=':',marker='1', markersize=20)
