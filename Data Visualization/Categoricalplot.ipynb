# %% [markdown]
# <a href="https://colab.research.google.com/github/rafi1105/Machine_Learning_colab/blob/main/Data%20Visualization/Categoricalplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Categorical Data Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ##countplot

# %%
sns.countplot(x=data['sex'], hue=data['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ##boxplot

# %%
sns.boxplot(y=data['day'], x=data['tip'],palette='rainbow')
# Out:
# /tmp/ipython-input-26-878068573.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data['day'], x=data['tip'],palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ##violinplot

# %%
sns.violinplot(x=data['day'], y=data['total_bill'],palette='rainbow')
# Out:
# /tmp/ipython-input-28-1888398275.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data['day'], y=data['total_bill'],palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ##stripplot

# %%
sns.stripplot(x=data['day'], y=data['total_bill'],jitter=True,palette='rainbow')
# Out:
# /tmp/ipython-input-29-59231607.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x=data['day'], y=data['total_bill'],jitter=True,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x=data['day'], y=data['total_bill'],palette='rainbow')
# Out:
# /tmp/ipython-input-30-724285802.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x=data['day'], y=data['total_bill'],palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x=data['day'], y=data['total_bill'],palette='rainbow')
sns.swarmplot(x=data['day'], y=data['total_bill'],color='black',size=3)
# Out:
# /tmp/ipython-input-31-3253774731.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data['day'], y=data['total_bill'],palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ##barplot

# %%
import numpy as np
sns.barplot(x=data['day'], y=data['total_bill'],estimator=np.sum) # estimator can be (mean,median,sum,std,min,max)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
